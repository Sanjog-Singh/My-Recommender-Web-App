# %%
import numpy as np
import pandas as pd

# %%
musics_df=pd.read_csv('2420_musics.csv')

# %%
musics_df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# ...

# %%
musics_df.shape
# Out:
# (2420, 5)

# %%
musics_df.isnull().sum()
# Out:
# Song-Name          0
# Singer/Artists    10
# Genre              0
# Album/Movie        3
# User-Rating        0
# dtype: int64

# %%
musics_df.dropna(inplace=True)

# %%
musics_df.duplicated().sum()
# Out:
# np.int64(16)

# %%
musics_df=musics_df.drop_duplicates()

# %%
musics_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
musics_df.shape
# Out:
# (2391, 5)

# %%
musics_df.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %%
musics_df['User-Rating']
# Out:
# 0       8.8/10
# 1       9.0/10
# 2       9.7/10
# 3       9.1/10
# 4       9.2/10
#          ...
# 2415    6.2/10
# 2416    7.2/10
# 2417    7.5/10
# 2418    6.5/10
# 2419    6.6/10
# Name: User-Rating, Length: 2391, dtype: object

# %%
l=[]
for i in musics_df['User-Rating']:
    l.append(i[:3])
l
# Out:
# ['8.8',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.2',
#  '9.1',
#  '9.2',
#  '9.5',
#  '9.2',
#  '9.6',
#  '8.8',
#  '8.4',
#  '9.1',
#  '9.2',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '9.2',
#  '9.2',
#  '9.5',
#  '8.6',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.2',
#  '9.5',
#  '9.4',
#  '8.7',
#  '9.3',
#  '9.3',
#  '9.5',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '8.4',
#  '8.4',
#  '8.8',
#  '9.2',
#  '9.2',
#  '9.6',
#  '9.6',
#  '9.0',
#  '9.1',
#  '8.5',
#  '9.5',
#  '8.5',
#  '9.7',
#  '8.9',
#  '9.6',
#  '8.5',
#  '9.1',
#  '8.7',
#  '8.6',
#  '9.3',
#  '9.7',
#  '8.9',
#  '9.0',
#  '9.0',
#  '9.3',
#  '9.3',
#  '9.1',
#  '9.0',
#  '9.7',
#  '9.2',
#  '9.1',
#  '9.0',
#  '8.9',
#  '9.5',
#  '9.5',
#  '9.7',
#  '9.0',
#  '8.1',
#  '8.1',
#  '9.5',
#  '9.1',
#  '8.6',
#  '9.4',
#  '9.0',
#  '9.0',
#  '9.6',
#  '9.3',
#  '9.0',
#  '9.2',
#  '9.3',
#  '9.1',
#  '8.6',
#  '9.5',
#  '9.5',
#  '9.0',
#  '9.4',
#  '9.2',
#  '9.6',
#  '9.3',
#  '7.7',
#  '9.2',
#  '9.3',
# ...

# %%
musics_df['User-Rating']=l
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_4496\2472386413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   musics_df['User-Rating']=l

# %%
musics_df['Album/Movie']=musics_df['Album/Movie'].str.replace(' ','')
musics_df['Singer/Artists']=musics_df['Singer/Artists'].str.replace(' ','')
musics_df
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_4496\899044566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   musics_df['Album/Movie']=musics_df['Album/Movie'].str.replace(' ','')
# C:\Users\singh\AppData\Local\Temp\ipykernel_4496\899044566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   musics_df['Singer/Artists']=musics_df['Singer/Artists'].str.replace(' ','')
#                                Song-Name  \
# 0                            Aankh Marey
# ...

# %%
musics_df['Singer/Artists']=musics_df['Singer/Artists'].str.replace(',',' ')
musics_df
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_4496\335498187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   musics_df['Singer/Artists']=musics_df['Singer/Artists'].str.replace(',',' ')
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
# ...

# %%
musics_df['tags']=musics_df['Singer/Artists']+musics_df['Genre']+musics_df['Album/Movie']+musics_df['User-Rating']
musics_df
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_4496\2212784022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   musics_df['tags']=musics_df['Singer/Artists']+musics_df['Genre']+musics_df['Album/Movie']+musics_df['User-Rating']
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
# ...

# %%
musics_df['tags'][0]
# Out:
# 'KumarSanu MikaSingh NehaKakkarBollywoodDanceSimmba8.8'

# %%
final_df=musics_df[['Song-Name','tags']]
final_df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# 0     KumarSanu MikaSingh NehaKakkarBollywoodDanceSi...
# 1     NehaKakkar TonyKakkarBollywoodDanceRomanticLuk...
# 2                 RanveerSinghBollywoodDanceGullyBoy9.7
# 3     JyoticaTangri Shaan SubhroGangulyBollywoodDanc...
# 4     AseesKaur RahatFatehAliKhan TanishkBagchiBolly...
# ...                                                 ...
# 2415                     MukeshBollywoodDanceSasural6.2
# ...

# %%
final_df['tags']=final_df['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_4496\3671300185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['tags']=final_df['tags'].apply(lambda x:x.lower())

# %%
final_df.head()
# Out:
#           Song-Name                                               tags
# 0       Aankh Marey  kumarsanu mikasingh nehakakkarbollywooddancesi...
# 1         Coca Cola  nehakakkar tonykakkarbollywooddanceromanticluk...
# 2  Apna Time Aayega              ranveersinghbollywooddancegullyboy9.7
# 3            Mungda  jyoticatangri shaan subhrogangulybollywooddanc...
# 4          Tere Bin  aseeskaur rahatfatehalikhan tanishkbagchibolly...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv= CountVectorizer(max_features=2391)

# %%
vectors=cv.fit_transform(final_df['tags']).toarray()

# %%
vectors.shape
# Out:
# (2391, 2391)

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(2391,))

# %%
cv.get_feature_names_out()
# Out:
# array(['18', '19', '559', ..., 'yoyohoneysinghbollywooddanceyaariyan8',
#        'yoyohoneysinghbollywooddanceyaariyan9',
#        'yrfbollywooddancechandni8'], shape=(2391,), dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
musics_similarity_scores=cosine_similarity(vectors)

# %%
musics_similarity_scores[0]
# Out:
# array([1., 0., 0., ..., 0., 0., 0.], shape=(2391,))

# %%
sorted(list(enumerate(musics_similarity_scores[0])),reverse=True,key=lambda x:x[1])[1:6]
# Out:
# [(11, np.float64(0.408248290463863)),
#  (136, np.float64(0.408248290463863)),
#  (202, np.float64(0.408248290463863)),
#  (367, np.float64(0.408248290463863)),
#  (406, np.float64(0.408248290463863))]

# %%
final_df.rename(columns={'Song-Name':'title'},inplace=True)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_4496\3777889314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.rename(columns={'Song-Name':'title'},inplace=True)

# %%
def recommend(music):
  music_index=final_df[final_df['title']==music].index[0]
  distances=musics_similarity_scores[music_index]
  music_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
  for i in music_list:
    print(final_df.iloc[i[0]].title)

# %%
recommend('Aankh Marey')
# Out:
# Poster Lagwa Do
# Hawa Hawa
# Piya More
# Dard Karaara
# Jumme Ki Raat

# %%
import pickle

# %%
pickle.dump(final_df,open('musics_model.pkl','wb'))
pickle.dump(musics_similarity_scores,open('musics_similarity_scores.pkl','wb'))
